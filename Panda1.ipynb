# %% [markdown]
# <a href="https://colab.research.google.com/github/robert2999/Analisis-de-datos/blob/main/Panda1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv(r'dataframe.csv')
df
# Out:
#   Nombre  Edad       Pais Automovil
# 0   Juan    35     Mexico        No
# 1  Pedro    41   Honduras        Si
# 2  Maria    28       Peru        Si
# 3  Laura    66  Argentina        No

# %% [markdown]
# Una serie es una columna del dataframe

# %%
df["Nombre"]
# Out:
# 0     Juan
# 1    Pedro
# 2    Maria
# 3    Laura
# Name: Nombre, dtype: object

# %%
df.Pais
# Out:
# 0       Mexico
# 1     Honduras
# 2         Peru
# 3    Argentina
# Name: Pais, dtype: object

# %%
df[["Edad","Automovil"]]
# Out:
#    Edad Automovil
# 0    35        No
# 1    41        Si
# 2    28        Si
# 3    66        No

# %%
data=pd.read_csv(r'ejemplo.csv')
data
# Out:
#            fecha    apertura        alto        bajo      cierre  Adj cierre  \
# 0     1999-12-31  146.843704  147.500000  146.250000  146.875000  104.415031
# 1     2000-01-03  148.250000  148.250000  143.875000  145.437500  103.393074
# 2     2000-01-04  143.531204  144.062500  139.640594  139.750000   99.349785
# 3     2000-01-05  139.937500  141.531204  137.250000  140.000000   99.527527
# 4     2000-01-06  139.625000  141.500000  137.750000  137.750000   97.928017
# ...          ...         ...         ...         ...         ...         ...
# 4625  2018-05-21  273.010010  273.980011  272.570007  273.369995  273.369995
# 4626  2018-05-22  273.959991  274.250000  272.239990  272.609985  272.609985
# 4627  2018-05-23  271.170013  273.390015  270.989990  273.359985  273.359985
# 4628  2018-05-24  272.910004  273.220001  270.779999  272.799988  272.799988
# 4629  2018-05-25  272.149994  272.859985  271.579987  272.149994  272.149994
#
#        volumen
# 0      3172700
# ...

# %%
df=pd.read_csv(r'dataframe.csv')
df
# Out:
#   Nombre  Edad       Pais Automovil
# 0   Juan    35     Mexico        No
# 1  Pedro    41   Honduras        Si
# 2  Maria    28       Peru        Si
# 3  Laura    66  Argentina        No

# %%
# esto te da las filas y columnas
df.shape
# Out:
# (4, 4)

# %%
# te da las filas
df.shape[0]
# Out:
# 4

# %%
# te da las filas
df.shape[1]
# Out:
# 4

# %%
df["casado"]=['si','no','si','no']

# %%
df
# Out:
#   Nombre  Edad       Pais Automovil casado
# 0   Juan    35     Mexico        No     si
# 1  Pedro    41   Honduras        Si     no
# 2  Maria    28       Peru        Si     si
# 3  Laura    66  Argentina        No     no

# %%
df.head()
# Out:
#   Nombre  Edad       Pais Automovil casado
# 0   Juan    35     Mexico        No     si
# 1  Pedro    41   Honduras        Si     no
# 2  Maria    28       Peru        Si     si
# 3  Laura    66  Argentina        No     no

# %%
data=pd.read_csv(r'ejemplo.csv')
data.head()
# Out:
#         fecha    apertura        alto        bajo    cierre  Adj cierre  \
# 0  1999-12-31  146.843704  147.500000  146.250000  146.8750  104.415031
# 1  2000-01-03  148.250000  148.250000  143.875000  145.4375  103.393074
# 2  2000-01-04  143.531204  144.062500  139.640594  139.7500   99.349785
# 3  2000-01-05  139.937500  141.531204  137.250000  140.0000   99.527527
# 4  2000-01-06  139.625000  141.500000  137.750000  137.7500   97.928017
#
#     volumen
# 0   3172700
# 1   8164300
# 2   8089800
# 3  12177900
# 4   6227200

# %%
data.tail()
# Out:
#            fecha    apertura        alto        bajo      cierre  Adj cierre  \
# 4625  2018-05-21  273.010010  273.980011  272.570007  273.369995  273.369995
# 4626  2018-05-22  273.959991  274.250000  272.239990  272.609985  272.609985
# 4627  2018-05-23  271.170013  273.390015  270.989990  273.359985  273.359985
# 4628  2018-05-24  272.910004  273.220001  270.779999  272.799988  272.799988
# 4629  2018-05-25  272.149994  272.859985  271.579987  272.149994  272.149994
#
#        volumen
# 4625  58025900
# 4626  52966400
# 4627  61021700
# 4628  76043800
# 4629  54842200

# %%
data.tail(2)
# Out:
#            fecha    apertura        alto        bajo      cierre  Adj cierre  \
# 4628  2018-05-24  272.910004  273.220001  270.779999  272.799988  272.799988
# 4629  2018-05-25  272.149994  272.859985  271.579987  272.149994  272.149994
#
#        volumen
# 4628  76043800
# 4629  54842200

# %%
df=pd.read_csv(r'dataframe.csv')
df
# Out:
#   Nombre  Edad       Pais Automovil
# 0   Juan    35     Mexico        No
# 1  Pedro    41   Honduras        Si
# 2  Maria    28       Peru        Si
# 3  Laura    66  Argentina        No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Nombre     4 non-null      object
#  1   Edad       4 non-null      int64
#  2   Pais       4 non-null      object
#  3   Automovil  4 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 260.0+ bytes

# %% [markdown]
# Para saber los valores repetidos de un valor se usa .values_count().Por ejemplo, si quiero saber si la edad de alguien se repite

# %%
df.Edad.value_counts()
# Out:
# Edad
# 35    1
# 41    1
# 28    1
# 66    1
# Name: count, dtype: int64

# %% [markdown]
# Como se muestra en la anterior tabla la edad 35 solo esta una vez igual con 41 , 28 y 66.

# %%
df.Automovil.value_counts()
# Out:
# Automovil
# No    2
# Si    2
# Name: count, dtype: int64

# %%
# con la funcion loc accedo al indice

# %%
df=pd.read_csv(r'dataframe.csv')
df
# Out:
#   Nombre  Edad       Pais Automovil
# 0   Juan    35     Mexico        No
# 1  Pedro    41   Honduras        Si
# 2  Maria    28       Peru        Si
# 3  Laura    66  Argentina        No

# %%
df.loc[len(df)]=["Laura",66,"Argentina","No"]
df
# Out:
#   Nombre  Edad       Pais Automovil
# 0   Juan    35     Mexico        No
# 1  Pedro    41   Honduras        Si
# 2  Maria    28       Peru        Si
# 3  Laura    66  Argentina        No
# 4  Laura    66  Argentina        No
# 5  Laura    66  Argentina        No

# %%
df
# Out:
#   Nombre  Edad       Pais Automovil
# 0   Juan    35     Mexico        No
# 1  Pedro    41   Honduras        Si
# 2  Maria    28       Peru        Si
# 3  Laura    66  Argentina        No
# 4  Laura    66  Argentina        No
# 5  Laura    66  Argentina        No

# %%
df=pd.read_csv(r'dataframe.csv')
df
# Out:
#   Nombre  Edad       Pais Automovil
# 0   Juan    35     Mexico        No
# 1  Pedro    41   Honduras        Si
# 2  Maria    28       Peru        Si
# 3  Laura    66  Argentina        No

# %%
df.loc[len(df)]=["Laura",66,"Argentina","No"]

# %%
df
# Out:
#   Nombre  Edad       Pais Automovil
# 0   Juan    35     Mexico        No
# 1  Pedro    41   Honduras        Si
# 2  Maria    28       Peru        Si
# 3  Laura    66  Argentina        No
# 4  Laura    66  Argentina        No

# %%
df.loc[len(df)]=["Alvaro",33,"Peru","Si"]

# %%
df
# Out:
#    Nombre  Edad       Pais Automovil
# 0    Juan    35     Mexico        No
# 1   Pedro    41   Honduras        Si
# 2   Maria    28       Peru        Si
# 3   Laura    66  Argentina        No
# 4   Laura    66  Argentina        No
# 5  Alvaro    33       Peru        Si

# %% [markdown]
# Si quiero en forma ascendente pongo entre parentesis (ascending=true,dropna=False), el dorpna es para que quite de la consulta los  valores nulos

# %%
# esto lo ordena de forma ascendente
df.Pais.sort_values()
# Out:
# 3    Argentina
# 4    Argentina
# 1     Honduras
# 0       Mexico
# 2         Peru
# 5         Peru
# Name: Pais, dtype: object

# %%
df.sort_values(by=['Nombre','Edad'])
# Out:
#    Nombre  Edad       Pais Automovil
# 5  Alvaro    33       Peru        Si
# 0    Juan    35     Mexico        No
# 3   Laura    66  Argentina        No
# 4   Laura    66  Argentina        No
# 2   Maria    28       Peru        Si
# 1   Pedro    41   Honduras        Si
