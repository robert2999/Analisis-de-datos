# %% [markdown]
# <a href="https://colab.research.google.com/github/robert2999/Analisis-de-datos/blob/main/Panda1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv(r'dataframe.csv')
df
# Out:
#   Nombre  Edad       Pais Automovil
# 0   Juan    35     Mexico        No
# 1  Pedro    41   Honduras        Si
# 2  Maria    28       Peru        Si
# 3  Laura    66  Argentina        No

# %% [markdown]
# Una serie es una columna del dataframe

# %%
df["Nombre"]
# Out:
# 0     Juan
# 1    Pedro
# 2    Maria
# 3    Laura
# Name: Nombre, dtype: object

# %%
df.Pais
# Out:
# 0       Mexico
# 1     Honduras
# 2         Peru
# 3    Argentina
# Name: Pais, dtype: object

# %%
df[["Edad","Automovil"]]
# Out:
#    Edad Automovil
# 0    35        No
# 1    41        Si
# 2    28        Si
# 3    66        No

# %%
data=pd.read_csv(r'ejemplo.csv')
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3282888948.py in <cell line: 0>()
# ----> 1 data=pd.read_csv(r'ejemplo.csv')
#       2 data
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ejemplo.csv'

# %%
df=pd.read_csv(r'dataframe.csv')
df
# Out:
#   Nombre  Edad       Pais Automovil
# 0   Juan    35     Mexico        No
# 1  Pedro    41   Honduras        Si
# 2  Maria    28       Peru        Si
# 3  Laura    66  Argentina        No

# %%
# esto te da las filas y columnas
df.shape
# Out:
# (4, 4)

# %%
# te da las filas
df.shape[0]
# Out:
# 4

# %%
# te da las filas
df.shape[1]
# Out:
# 4

# %%
df["casado"]=['si','no','si','no']

# %%
df

# %%
df.head()

# %%
data=pd.read_csv(r'ejemplo.csv')
data.head()

# %%
data.tail()

# %%
data.tail(2)

# %%
df=pd.read_csv(r'dataframe.csv')
df

# %%
df.info()

# %% [markdown]
# Para saber los valores repetidos de un valor se usa .values_count().Por ejemplo, si quiero saber si la edad de alguien se repite

# %%
df.Edad.value_counts()

# %% [markdown]
# Como se muestra en la anterior tabla la edad 35 solo esta una vez igual con 41 , 28 y 66.

# %%
df.Automovil.value_counts()

# %%
# con la funcion loc accedo al indice

# %%
df=pd.read_csv(r'dataframe.csv')
df

# %%
df.loc[len(df)]=["Laura",66,"Argentina","No"]
df
# Out:
#   Nombre  Edad       Pais Automovil
# 0   Juan    35     Mexico        No
# 1  Pedro    41   Honduras        Si
# 2  Maria    28       Peru        Si
# 3  Laura    66  Argentina        No
# 4  Laura    66  Argentina        No

# %%
df

# %%
df=pd.read_csv(r'dataframe.csv')
df
# Out:
#   Nombre  Edad       Pais Automovil
# 0   Juan    35     Mexico        No
# 1  Pedro    41   Honduras        Si
# 2  Maria    28       Peru        Si
# 3  Laura    66  Argentina        No

# %%
df.loc[len(df)]=["Laura",66,"Argentina","No"]

# %%
df
# Out:
#   Nombre  Edad       Pais Automovil
# 0   Juan    35     Mexico        No
# 1  Pedro    41   Honduras        Si
# 2  Maria    28       Peru        Si
# 3  Laura    66  Argentina        No
# 4  Laura    66  Argentina        No

# %%
df.loc[len(df)]=["Alvaro",33,"Peru","Si"]

# %%
df
# Out:
#    Nombre  Edad       Pais Automovil
# 0    Juan    35     Mexico        No
# 1   Pedro    41   Honduras        Si
# 2   Maria    28       Peru        Si
# 3   Laura    66  Argentina        No
# 4   Laura    66  Argentina        No
# 5  Alvaro    33       Peru        Si

# %% [markdown]
# Si quiero en forma ascendente pongo entre parentesis (ascending=true,dropna=False), el dorpna es para que quite de la consulta los  valores nulos

# %%
# esto lo ordena de forma ascendente
df.Pais.sort_values()
# Out:
# 3    Argentina
# 4    Argentina
# 1     Honduras
# 0       Mexico
# 2         Peru
# 5         Peru
# Name: Pais, dtype: object

# %%
df.sort_values(by=['Nombre','Edad'])
# Out:
#    Nombre  Edad       Pais Automovil
# 5  Alvaro    33       Peru        Si
# 0    Juan    35     Mexico        No
# 3   Laura    66  Argentina        No
# 4   Laura    66  Argentina        No
# 2   Maria    28       Peru        Si
# 1   Pedro    41   Honduras        Si

# %%
df
# Out:
#    Nombre  Edad       Pais Automovil
# 0    Juan    35     Mexico        No
# 1   Pedro    41   Honduras        Si
# 2   Maria    28       Peru        Si
# 3   Laura    66  Argentina        No
# 4   Laura    66  Argentina        No
# 5  Alvaro    33       Peru        Si

# %% [markdown]
# Filtrar segun las filas que contengan a Peru como pais

# %%
df[df.Pais=='Peru']
# Out:
#    Nombre  Edad  Pais Automovil
# 2   Maria    28  Peru        Si
# 5  Alvaro    33  Peru        Si

# %%
# poner & que es igual a un y
df[(df.Pais=='Peru') & (df.Edad>=30)]
# Out:
#    Nombre  Edad  Pais Automovil
# 5  Alvaro    33  Peru        Si

# %%
df
# Out:
#    Nombre  Edad       Pais Automovil
# 0    Juan    35     Mexico        No
# 1   Pedro    41   Honduras        Si
# 2   Maria    28       Peru        Si
# 3   Laura    66  Argentina        No
# 4   Laura    66  Argentina        No
# 5  Alvaro    33       Peru        Si

# %% [markdown]
# Metodo que tenga un atributo

# %%
df[df.Pais.str.contains('Peru')]
# Out:
#    Nombre  Edad  Pais Automovil
# 2   Maria    28  Peru        Si
# 5  Alvaro    33  Peru        Si

# %%
# supongamos que yo me olvido un dato que estaba buscando
# pero recuerdo que comienza con una letra en especifico
# y eso se puede hacer
# con la funcion startswith
df[df.Pais.str.startswith('A')]
# Out:
#   Nombre  Edad       Pais Automovil
# 3  Laura    66  Argentina        No
# 4  Laura    66  Argentina        No

# %% [markdown]
# Cambio de indice

# %%
df
# Out:
#    Nombre  Edad       Pais Automovil
# 0    Juan    35     Mexico        No
# 1   Pedro    41   Honduras        Si
# 2   Maria    28       Peru        Si
# 3   Laura    66  Argentina        No
# 4   Laura    66  Argentina        No
# 5  Alvaro    33       Peru        Si

# %% [markdown]
# Los indices son del 0 al 5 , pero en este caso lo cambiamos por nombres

# %%
df.set_index('Nombre')
# Out:
#         Edad       Pais Automovil
# Nombre
# Juan      35     Mexico        No
# Pedro     41   Honduras        Si
# Maria     28       Peru        Si
# Laura     66  Argentina        No
# Laura     66  Argentina        No
# Alvaro    33       Peru        Si

# %% [markdown]
# Para que se reemplace o se quede fijamente debemos agregarle inplace=true

# %%
df
# Out:
#    Nombre  Edad       Pais Automovil
# 0    Juan    35     Mexico        No
# 1   Pedro    41   Honduras        Si
# 2   Maria    28       Peru        Si
# 3   Laura    66  Argentina        No
# 4   Laura    66  Argentina        No
# 5  Alvaro    33       Peru        Si

# %% [markdown]
# Supongamos que nos dicen que lo volvamos a la anterior vez

# %%
df.drop('index',axis=1,inplace=True)
df
# Out:
#    Nombre  Edad       Pais Automovil
# 0    Juan    35     Mexico        No
# 1   Pedro    41   Honduras        Si
# 2   Maria    28       Peru        Si
# 3   Laura    66  Argentina        No
# 4   Laura    66  Argentina        No
# 5  Alvaro    33       Peru        Si

# %%
df
# Out:
#    index  Nombre  Edad       Pais Automovil
# 0      0    Juan    35     Mexico        No
# 1      1   Pedro    41   Honduras        Si
# 2      2   Maria    28       Peru        Si
# 3      3   Laura    66  Argentina        No
# 4      4   Laura    66  Argentina        No
# 5      5  Alvaro    33       Peru        Si

# %%
rob=df.set_index('Pais')

# %%
rob.drop('index',axis=1,inplace=True)
rob
# Out:
#            Nombre  Edad Automovil
# Pais
# Mexico       Juan    35        No
# Honduras    Pedro    41        Si
# Peru        Maria    28        Si
# Argentina   Laura    66        No
# Argentina   Laura    66        No
# Peru       Alvaro    33        Si

# %%
rob.sort_index(ascending=False)
# Out:
#            Nombre  Edad Automovil
# Pais
# Peru        Maria    28        Si
# Peru       Alvaro    33        Si
# Mexico       Juan    35        No
# Honduras    Pedro    41        Si
# Argentina   Laura    66        No
# Argentina   Laura    66        No

# %%
df
# Out:
#    Nombre  Edad       Pais Automovil
# 0    Juan    35     Mexico        No
# 1   Pedro    41   Honduras        Si
# 2   Maria    28       Peru        Si
# 3   Laura    66  Argentina        No
# 4   Laura    66  Argentina        No
# 5  Alvaro    33       Peru        Si

# %%
# el loc se puede localizar con los indices
df.loc[0:3]
# Out:
#   Nombre  Edad       Pais Automovil
# 0   Juan    35     Mexico        No
# 1  Pedro    41   Honduras        Si
# 2  Maria    28       Peru        Si
# 3  Laura    66  Argentina        No

# %%
df.loc[df.Pais=='Peru']
# Out:
#    Nombre  Edad  Pais Automovil
# 2   Maria    28  Peru        Si
# 5  Alvaro    33  Peru        Si

# %% [markdown]
# Agrupacion por enteros

# %%
df
# Out:
#    Nombre  Edad       Pais Automovil
# 0    Juan    35     Mexico        No
# 1   Pedro    41   Honduras        Si
# 2   Maria    28       Peru        Si
# 3   Laura    66  Argentina        No
# 4   Laura    66  Argentina        No
# 5  Alvaro    33       Peru        Si

# %%
df.iloc[4]
# Out:
# Nombre           Laura
# Edad                66
# Pais         Argentina
# Automovil           No
# Name: 4, dtype: object

# %%
df.iloc[[4,2,5]]
# Out:
#    Nombre  Edad       Pais Automovil
# 4   Laura    66  Argentina        No
# 2   Maria    28       Peru        Si
# 5  Alvaro    33       Peru        Si

# %%
df.iloc[2:5]
# Out:
#   Nombre  Edad       Pais Automovil
# 2  Maria    28       Peru        Si
# 3  Laura    66  Argentina        No
# 4  Laura    66  Argentina        No

# %% [markdown]
# Ahora, agrupamos por groupby

# %%
df
# Out:
#    Nombre  Edad       Pais Automovil
# 0    Juan    35     Mexico        No
# 1   Pedro    41   Honduras        Si
# 2   Maria    28       Peru        Si
# 3   Laura    66  Argentina        No
# 4   Laura    66  Argentina        No
# 5  Alvaro    33       Peru        Si

# %%
df.groupby('Pais')

# %%
list(df.groupby('Pais'))
# Out:
# [('Argentina',
#     Nombre  Edad       Pais Automovil
#   3  Laura    66  Argentina        No
#   4  Laura    66  Argentina        No),
#  ('Honduras',
#     Nombre  Edad      Pais Automovil
#   1  Pedro    41  Honduras        Si),
#  ('Mexico',
#     Nombre  Edad    Pais Automovil
#   0   Juan    35  Mexico        No),
#  ('Peru',
#      Nombre  Edad  Pais Automovil
#   2   Maria    28  Peru        Si
#   5  Alvaro    33  Peru        Si)]

# %%
list(df.groupby('Automovil'))
# Out:
# [('No',
#     Nombre  Edad       Pais Automovil
#   0   Juan    35     Mexico        No
#   3  Laura    66  Argentina        No
#   4  Laura    66  Argentina        No),
#  ('Si',
#      Nombre  Edad      Pais Automovil
#   1   Pedro    41  Honduras        Si
#   2   Maria    28      Peru        Si
#   5  Alvaro    33      Peru        Si)]
